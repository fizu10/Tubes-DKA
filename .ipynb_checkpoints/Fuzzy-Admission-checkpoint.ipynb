# %%
print("Tugas Besar Dasar Kecerdasan Artificial")
print("Menentukan tingkat kelulusan seseorang memasuki perguruan tinggi pascasarjana berdasarkan TOEFL, GRE, CGRE Score")
# Out:
# Tugas Besar Dasar Kecerdasan Artificial
# Menentukan tingkat kelulusan seseorang memasuki perguruan tinggi pascasarjana berdasarkan TOEFL, GRE, CGRE Score

# %%
print("Muhammad Abdillah Hafizh (103012300369)")
print("Bintang Kantata")
print("Nabil")
# Out:
# Muhammad Abdillah Hafizh (103012300369)
# Bintang Kantata
# Nabil

# %%
#import libraries
import numpy as np
import pandas as pd
import os
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %%
#memasukkan file
df = pd.read_csv("Admission_predict.csv")

df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
# Hapus kolom "Serial No."
df.drop(columns=["Serial No."], inplace=True)

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
#cek apakah ada missing value
df.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
# Cek duplikat
df.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.boxplot(data=X_scaled)
plt.xticks(rotation=45)
plt.title("Boxplot untuk Deteksi Outlier")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Heatmap Korelasi")
plt.show()

# %%
#mendefinisikan input dan output
GRE = ctrl.Antecedent(np.arange(0, 1.01, 0.01), 'GRE')
TOEFL = ctrl.Antecedent(np.arange(0, 1.01, 0.01), 'bmi')
CGRE = ctrl.Antecedent(np.arange(0, 1.01, 0.01), 'CGRE')
lulus = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'lulus')

# %%
#fungsi keanggotaan GRE
GRE['low']=fuzz.trimf(GRE.universe, [0.0, 0.3, 0.5])
GRE['med']=fuzz.trimf(GRE.universe, [0.3, 0.5, 0.7])
GRE['high']=fuzz.trimf(GRE.universe, [0.5, 0.7, 1.0])

#fungsi keangotaan TOEFl
TOEFL['low']=fuzz.trimf(TOEFL.universe, [0.0, 0.3, 0.5])
TOEFL['med']=fuzz.trimf(TOEFL.universe, [0.3, 0.5, 0.7])
TOEFL['high']=fuzz.trimf(TOEFL.universe, [0.5, 0.7, 1.0])

#fungsi keanggotaan CGPA
CGPA['low']=fuzz.trimf(CGPA.universe, [0.0, 0.4, 0.6])
CGPA['med']=fuzz.trimf(CGPA.universe, [0.4, 0.6, 0.8])
CGPA['high']=fuzz.trimf(CGPA.universe, [0.5, 0.7, 1.0])
